# %%
 from sklearn.linear_model import LinearRegression
 from sklearn.linear_model import LogisticRegression
 import seaborn as sns
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt
 from sklearn.model_selection import train_test_split
 df=pd.read_csv('/content/exams.csv')
 h=df.head(10)
 t=df.tail(10)
 print(df.shape)
 for i in range(120,110,-1):
  df.drop([i],axis=0,inplace=True)
 for i in range(10):
  df.drop([i],axis=0,inplace=True)
 dfmt=pd.concat([h,t],axis=0)
 dfmt.to_csv("test_file.csv")
 data=pd.read_csv('/content/test_file.csv')
 print(data)
# Out:
# (1000, 8)
#     Unnamed: 0  gender race/ethnicity parental level of education  \
# 0            0  female        group D                some college
# 1            1    male        group D          associate's degree
# 2            2  female        group D                some college
# 3            3    male        group B                some college
# 4            4  female        group D          associate's degree
# 5            5    male        group C            some high school
# 6            6  female        group E          associate's degree
# 7            7  female        group B            some high school
# 8            8    male        group C            some high school
# 9            9  female        group C           bachelor's degree
# 10         990  female        group C            some high school
# 11         991  female        group A          associate's degree
# 12         992    male        group A          associate's degree
# 13         993    male        group D            some high school
# 14         994  female        group B          associate's degree
# 15         995    male        group C                some college
# 16         996    male        group C                some college
# 17         997  female        group A                 high school
# 18         998    male        group E                 high school
# 19         999    male        group D                 high school
#
#            lunch test preparation course  math score  reading score  \
# 0       standard               completed          59             70
# 1       standard                    none          96             93
# 2   free/reduced                    none          57             76
# 3   free/reduced                    none          70             70
# 4       standard                    none          83             85
# 5       standard                    none          68             57
# 6       standard                    none          82             83
# 7       standard                    none          46             61
# 8       standard                    none          80             75
# 9       standard               completed          57             69
# 10      standard                    none          70             77
# 11      standard                    none          72             77
# 12  free/reduced               completed          75             67
# 13      standard                    none          83             74
# 14      standard                    none          82             97
# 15      standard                    none          77             77
# 16      standard                    none          80             66
# 17      standard               completed          67             86
# 18      standard                    none          80             72
# 19      standard                    none          58             47
#
#     writing score
# 0              78
# 1              87
# 2              77
# 3              63
# 4              86
# 5              54
# 6              80
# 7              58
# 8              73
# 9              77
# 10             76
# 11             77
# 12             67
# 13             80
# 14             90
# 15             71
# 16             66
# 17             86
# 18             62
# 19             45

# %%
data=data.sample(frac=1)
data.head(10)
x=data[["reading score"]]
y=data["writing score"]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
acc=model.score(X_test,y_test).round(2)
y_pred = model.predict(X_test)
print(acc,'\n',y_pred)
sns.heatmap([y_test,y_pred])
# Out:
# 0.85
#  [80.71616979 73.44320071 57.07902028 72.53407957]
# <Axes: >
